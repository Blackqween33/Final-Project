# %%
import pandas as pd
import numpy as nb
import openpyxl as op
import seaborn as sn
from datetime import datetime as dt
import pandas as pd
import numpy as np
import scipy
import statsmodels
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### Loading Data

# %%
incident_df = pd.read_excel('C:/Users/brigh/OneDrive/Desktop/Detail_Incident Scrubbed.xlsx')

# %% [markdown]
# # Data Wrangling

# %%
incident_df2 = incident_df.set_index('Incident ID')

# %%
incident_df2_top = incident_df.head()

# %%
incident_df2
# Out:
#              Priority                 Category  # Reassignments  \
# Incident ID
# IM0034604           1                 incident              0.0
# IM0035403           1                 incident              1.0
# IM0037024           1                 incident              0.0
# IM0000944           2                 incident              5.0
# IM0001225           2                 incident              1.0
# ...               ...                      ...              ...
# IM0047033           5  request for information              0.0
# IM0047040           5  request for information              0.0
# IM0047048           5                 incident              1.0
# IM0047050           5                 incident              3.0
# IM0047055           5                 incident              0.0
#
#                        Open Time          Reopen Time        Resolved Time  \
# Incident ID
# IM0034604    06/02/2014 09:40:35  12/02/2014 12:00:18  12/02/2014 12:01:14
# IM0035403    10/02/2014 09:20:28  12/02/2014 12:02:45  12/02/2014 12:03:01
# IM0037024    15/02/2014 10:29:49  17/02/2014 11:51:27  17/02/2014 11:54:21
# IM0000944    27/09/2013 08:52:38                  NaN  01/10/2013 18:20:07
# IM0001225    01/10/2013 08:18:24                  NaN                  NaN
# ...                          ...                  ...                  ...
# IM0047033    31/03/2014 12:44:51                  NaN  31/03/2014 14:10:43
# IM0047040    31/03/2014 13:42:26                  NaN  31/03/2014 15:41:57
# IM0047048    31/03/2014 15:04:27                  NaN  31/03/2014 16:31:53
# IM0047050    31/03/2014 15:55:07  31/03/2014 16:21:15  31/03/2014 17:20:03
# IM0047055    31/03/2014 15:28:22                  NaN  31/03/2014 15:32:37
#
#                       Close Time  Handle Time (Hours)    CI Name  \
# Incident ID
# IM0034604    12/02/2014 12:01:18                 30.0  WBA000058
# IM0035403    12/02/2014 12:03:05                 23.0  SUB000523
# IM0037024    17/02/2014 11:54:24                  1.0  WBA000068
# IM0000944    01/10/2013 18:23:03                 24.0  WBA000148
# IM0001225    01/10/2013 15:34:38                  7.0  SBA000759
# ...                          ...                  ...        ...
# IM0047033    31/03/2014 14:10:45                  1.0  WBA000124
# IM0047040    31/03/2014 15:42:01                  1.0  OVR000033
# IM0047048    31/03/2014 16:32:33                  1.0  WBA000124
# IM0047050    31/03/2014 17:20:06                  1.0  SBA000842
# IM0047055    31/03/2014 15:32:40                  0.0  SUB000431
#
#                     CI Type                CI Subtype Service Component WBS  \
# Incident ID
# IM0034604       application     Web Based Application             WBS000073
# IM0035403    subapplication     Web Based Application             WBS000073
# IM0037024       application     Web Based Application             WBS000171
# IM0000944       application     Web Based Application             WBS000172
# IM0001225       application  Server Based Application             WBS000296
# ...                     ...                       ...                   ...
# IM0047033       application     Web Based Application             WBS000088
# IM0047040           no type                no subtype             WBS000118
# IM0047048       application     Web Based Application             WBS000088
# IM0047050       application  Server Based Application             WBS000199
# IM0047055    subapplication     Web Based Application             WBS000066
#
#              KM number # Related Interactions
# Incident ID
# IM0034604    KM0002043               Software
# IM0035403    KM0000818                   Data
# IM0037024    KM0000697               Hardware
# IM0000944    KM0000697                  Other
# IM0001225    KM0001031               Software
# ...                ...                    ...
# IM0047033    KM0000611                  Other
# IM0047040    KM0001172         Operator error
# IM0047048    KM0000611                  Other
# IM0047050    KM0000940             User error
# IM0047055    KM0000603               Software
#
# [46606 rows x 14 columns]

# %%
incident_df2['Incident ID'].corr(incident_df2['Resolved Time'])
